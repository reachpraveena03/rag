# %%
# !pip install -Uq llama-index llama-parse

# %%
import nest_asyncio

from llama_index.llms.openai import OpenAI
from llama_index.core import VectorStoreIndex
from IPython.display import Image, Markdown

from llama_parse import LlamaParse

from llama_index.core.node_parser import MarkdownElementNodeParser

# %%
nest_asyncio.apply()

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-Wd1zjyZIKZxl5G6M0T91JB3qp2MK4miCNpy9NsgPVuC-IKSTIbMPmL4BKBInnErFYAInMWTjccT3BlbkFJeH0GYkvI2sxaroWfJYnqM2tGIXZ-CuKcKevoBtXiDbhnT1-OMRqFxp-YT0TTYGwU71xvMzqk"

llm_gpt4o_mini = OpenAI(model="gpt-4o-mini")

# %%
parser = LlamaParse(
    api_key='llx-IIIyrVjaSMWEXJaZB9M5wRqvEqkIEBfUARzK9b9E7Ozbzp',
    result_type="markdown",
)

documents = parser.load_data("/content/Centralized Repository.xlsx")
# Out:
# Started parsing the file under job_id ca8d16c6-4415-4d8f-855c-e24d312d1065

# %%
len(documents)
# Out:
# 4

# %%
print(documents[1].get_content())
# Out:
# # CWM
#
# | | | | |Data Points to measure (art of the possible)| | | | | | | | |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |Name|WT, CWM, SOW|Issue| | | | | | | | | | |
# | |Topics| | | | | | | | | | | |
# | |first step|second step|Advanced|Reports to use from Data Warehouse/Insights Hub|Possible Solutions|Data Points to measure solution success|Item Number|Reviewer Name|Reviewer Comments (enter 'no changes' if no comments needed)| | | |
# |Gigi|WT, CWM, SOW|Assignment Updates|Cost Center Changes|•	Enable the ROC (Recruiting Operations Center) to assist with routine cost center updates.| | | | | | | | |
# |•	Ensure the cost center change is reflected across all relevant fields:| | | | | | | | | | | | |
# |•	Assignment details| | | | | | | | | | | | |
# |•	Job requisition (determine if a new requisition or different approvers are needed)| | | | | | | | | | | | |
# |•	Update the manager and business unit if applicable.| | | | | | | | | | | | |
# |•	Run a VMS report post-update to confirm all changes were applied correctly.|•	Document the full cost center change process in a formal SOP (Standard Operating Procedure).| | | | | | | | | | | |
# |•	Audit historical changes to identify trends or recurring issues.| | | | | | | | | | | | |
# |•	Automate notifications or workflows for cost center updates to reduce manual errors.| |Intermediate/Advanced:| | | | | | | | | | |
# |- Custom Analytics: TAPFIN Interactive Dashboard is a report housing relevant backup data that could be used to assist with project auditing purposes|If you have billing and invoicing errors, check the cost centers and business units of the worker.  See if the errors come from the same ROC/PMO team member and conduct training to ensure they understand the configuration of the cost centers and how they affect billing.|Compare billing/invoicing errors from a previous period to a current period after a resolution was put in place.|3| | | | | | | | | |
# |Gigi|WT, CWM, SOW|Assignment Updates|Business Unit Changes|•	PM & RM Enable the ROC to help complete routine updates| | | | | | | | |
# |•	RP Ensure business unit changes are updated in all necessary fields (assignment, manager business unit, etc.)| | | | | | | | | | | | |
# |•	RP Ensure cost center and manager is updated if applicable.| | | | | | | | | | | | |
# |•	RP Run VMS report after to ensure all is completed correctly.|PM should ensure process is documented in SOP| |Intermediate/Advanced:| | | | | | | | | |
# |- Custom Analytics: TAPFIN Interactive Dashboard is a report housing relevant backup data that could be used to assist with project auditing purposes|If you have billing and invoicing errors, check the cost centers and business units of the worker.  See if the errors come from the same ROC/PMO team member and conduct training to ensure they understand the configuration of the cost centers and how they affect billing.| |3| | | | | | | | | |
# |Gigi|CWM, SOW|Assignment Updates|Extending large quantites of workers at one time (Mass extenstions)|Use an upload feature to quickly extend large groups of workers or data at one time:| | | | | | | | |
# |•	Enter Gemini ticket to obtain template needed to do upload in VMS.| | | | | | | | | | | | |
# |•	Run VMS report on active workers including any required data for the upload template (unique ID, worker name, end date, new end date, etc.).| | | | | | | | | | | | |
# |•	Complete template from Gemini and follow instructions to upload or attach to Gemini ticket for VMS analyst to upload.| | | | | | | | | | | | |
# |•	Run VMS report after upload to ensure all is correct.| | |Intermediate/Advanced:| | | | | | | | | |
# |- Custom Analytics: TAPFIN Interactive Dashboard is a report housing relevant backup data that could be used to assist with project auditing purposes|If you have a request to extend a large amount of workers, there are quick steps you can take time to make changes to assignments no matter which VMS you are using.|Time savings to manually update assignments vs the time to create the upload template|3| | | | | | | | | |
# |Gigi|CWM, SOW|Assignment Updates|Ensuring managers are entering extensions|Ensure the VMS is set up to send reminder emails to managers in enough time for approvals (example: at 30 days, 15, days & 7 days)| | | | | | | | |
# |•	Use the ROC to send reminder emails direct from MSP mailbox.  PMO should watch for undelivered email and make corrections as needed.| | | | | | | | | | | | |
# |•	Monitor to see how many extensions are pending and why.  Are there specific groups or managers?  Do they have issues accessing tool?  For example, Light Industrial managers may not have a computer in the warehouse to enter extensions or the manager’s email may be incorrect in the VMS, or the manager may no longer working at client, etc.|•	Ensure the final notification includes the worker will be terminated (and systems/badge access) as assignment completed on xx/xx date due to no response.  Have your program sponsor copied if they are agreeable.| | | | | | | | | | | |
# |•	Check to ensure there aren’t issue with emails being delivered (i.e. emails going to spam folder, manager notifications being turned off, etc.).| | | | | | | | | | | | |
# |•	For managers with multiple workers, investigate to see if VMS can send one daily reminder instead of individual notifications.  (Fieldglass has this feature.)| | | | | | | | | | | | |
# |•	Ensure up-coming end dates are featured on the PMO’s VMS dashboard, include tiers with enough time to prompt PMO and managers.| |Intermediate/Advanced:| | | | | | | | | | |
# |- Insights Hub: Headcount Insight| | | | | | | | | | | | |
# |- Custom Analytics: TAPFIN Interactive Dashboard|If your hiring managers are not extending workers timely, there are automated reminders and processes you can follow to encourage them to change the results.|Compare dates managers requested extensions in the past to the dates they entered once a process was enhanced/changed or was implemented.|3| | | | | | | | | |
# |Kristin|CWM|Assignment Updates|Worker Promotions|•	When a worker is promoted to a new role, the TAPFIN RP (Resource Professional) is responsible for communicating the promotion as a job offer to the supplier. The supplier must confirm whether the worker accepts or declines the promotion. The Client Manager should not directly offer the promotion to the contingent worker.| | | | | | | | |
# |•	Once the promotion is accepted, the TAPFIN RP must create a new job posting and work order aligned with the new job title.| | | | | | | | | | | | |
# |•	If a tenure discount is already applied to the worker's current work order, this discount will automatically carry over to their new job title. The TAPFIN RP should ensure that comprehensive comments are added to the comment section for tenure tracking purposes.| | | | | | | | | | | | |
# | |* Does the program have a reclassification process?  Is there an integration between the VMS and internal Client systems that need to be taken into consideration?| |Not tracked in TDW - unreportable by BI| |When a worker is promoted it should be for a future start date. The VMS should be adjusted to the workers new job title, rate, etc. prior to the worker changing roles.|3| | | | | | |
# |CWM Team - Gigi|WT, CWM, SOW|Audits - Client|Client Audits (security, IT, financial, etc.)|Be sure the PM and Delivery Director is brought in immediately on any audits the client requests.| | | | | | | | |
# |PMs should add any reports the client requests audits for to their weekly audit list to ensure compliance.| | | | | | | | | | | | |
# |PM should review any audit findings to determine if additional training on policies and processes are needed.  Continue to run reports on those items until report/audit comes back with no findings.| | | | | | | | | | | | |
# || | |Not tracked in TDW - unreportable by BI|If a client audit returns findings, conduct thorough investigations to understand the root causes of discrepancies and implement policies and procedures to prevent future findings.  Generate reports to run audits and proactively identify findings and resolve prior to client audit request.| |5| | | | | | |
# |Arch|WT, CWM, SOW|Audits - Internal TAPFIN|internal TAPFIN Audits - what do they tell us and what should they be used for (supplier compliance, pay rate audits etc (that you can then feed into scorecards)|All programs should have audits in place. It is the responsibility of the delivery team to work with the Shared Services or whichever team does the audits for that region to set up the process even before launch. Ideal is to conduct monthly audits as this will ensure that they are done regularly, and make sure suppliers are staying on top of data integrity since they will be autidted every month. You want audits for compliance checks to ensure they are being done before the worker starts. The PMO team will need to create a report of all new hires in that month so the audit team can reach out to the suppliers.| | | | | | | | |
# |Audits should also be in place for pay rates. The PMO needs to set up a report for all new hires with pay rates and bill rates and schedule the report to be delivered to the audit team.| | | | | | | | | | | | |
# |These audit results must be part of the supplier scorecard if you want to ensure your suppliers adhere to the standards.| | | | | | | | | | | | |
# |What you are auditing and the impact of failures must be added to the supplier packets and part of the communication and education that the PMO provides. This ensures they understand and they will usually have an administrative person who will be ready to get the audit requests from our Shared Services team. If a supplier does not get the info to the audit team, they should be considered failed and it should be reflected in their scorecards. Ongoing non-compliance should escalate to suspension from new reqs for a period of time, or eventual termination from the program. The time periods can vary depending on client industry or risk profile. For example, any clients who have medicial roles, or roles that touch chemicals or finacial institutions may be more severe in the consequences|More advanced audits can look at| |Intermediate/Advanced:| | | | | | | | | |
# |- BI Team may be able to create reporting for worker start compliance IF the VMS has the option to add field needed to track worker start compliance. Otherwise audits are not tracked in TDW and are unreportable by BI| | |6| | | | | | | | | |
# |Gigi|WT, CWM, SOW|Audits - Internal TAPFIN|Data Integrity|Ensuring data integrity in your Vendor Management Software (VMS) is crucial for maintaining accurate and reliable information.  Every day at the end of the day, each team member should run reports to ensure any data entered during the day was entered correctly.| | | | | | | | |
# |1.	Data Validation:| | | | | | | | | | | | |
# |•	Check for Missing Data: Ensure all required fields are populated.| | | | | | | | | | | | |
# |•	Verify Data Formats: Confirm that data entries follow the correct format (e.g., dates, currency).| | | | | | | | | | | | |
# |•	Consistency Checks: Compare data across different sources to ensure consistency.| | | | | | | | | | | | |
# |2.	Data Cleansing:| | | | | | | | | | | | |
# |•	Remove Duplicates: Identify and eliminate duplicate records.| | | | | | | | | | | | |
# |•	Correct Errors: Fix any inaccuracies or typos in the data.| | | | | | | | | | | | |
# |•	Standardize Data: Ensure uniformity in data entries (e.g., using the same units of measurement).| | | | | | | | | | | | |
# |3.	Data Integration:| | | | | | | | | | | | |
# |•	Consolidate Data Sources: Integrate data from various sources to create a unified view.| | | | | | | | | | | | |
# |•	Ensure Compatibility: Make sure different systems and tools can communicate effectively.| | | | | | | | | | | | |
# |Examples of data fields on the VMS assignment/project report to check:| | | | | | | | | | | | |
# |•	Pay Rate/Bill Rate| | | | | | | | | | | | |
# |•	Mark ups (payroll/recruited)| | | | | | | | | | | | |
# |•	Manager to Cost Center to Business Unit| | | | | | | | | | | | |
# |•	End Dates| | | | | | | | | | | | |
# |•	Tenure Dates & calculations - ensure no one is approaching client tenure policy (or over it)| | | | | | | | | | | | |
# |•	OT/DT rates/calculations| | | | | | | | | | | | |
# |•	Exempt/Non-Exempt classification| | | | | | | | | | | | |
# |•	Worker classification (W2/IC...)| | | | | | | | | | | | |
# |•	Sales tax added where required|PMs should be running reports daily on entire program to ensure accuracy and identify any training opportunities or reminders that need to occur to prevent further errors.| | | | | | | | | | | |
# |Regular Audits:| | | | | | | | | | | | |
# |•	Conduct Periodic Reviews: Regularly audit the data to identify and rectify issues.| | | | | | | | | | | | |
# |•	Automate Audits: Use automated tools (BOT, excel formulas) to continuously monitor data integrity.| | | | | | | | | | | | |
# | | |Intermediate/Advanced:| | | | | | | | | | |
# |- BI team provides backup data for spend, headcount, TTF, Attrition, Tenure, Requisition, and ratecard compliance (where applicable) in the TAPFIN Interactive dashboard housed in Custom Analytics. Recommendation to utilize this backup data to assist with data integrity of VMS. If additional fields are needed to assist please contact your BI Analyst for additional buildout| | | | | | | | | | | | |
# | |1.	If Data Shows Inconsistencies:| | | | | | | | | | | |
# |•	Implement Data Governance Policies: Establish clear guidelines for data entry and management.| | | | | | | | | | | | |
# |•	Train Staff: Provide training to ensure all team members understand the importance of data integrity and how to maintain it.| | | | | | | | | | | | |
# |2.	If Data Indicates Errors or Omissions:| | | | | | | | | | | | |
# |•	Enhance Data Entry Processes: Improve the processes for data entry to reduce errors.| | | | | | | | | | | | |
# |•	Use Data Validation Tools: Implement tools that automatically validate data as it is entered.| | | | | | | | | | | | |
# |3.	If Data Highlights Integration Issues:| | | | | | | | | | | | |
# |•	Invest in Integration Solutions: Use middleware or integration platforms to ensure seamless data flow between systems.| | | | | | | | | | | | |
# |•	Standardize Data Formats: Ensure all systems use standardized data formats to avoid compatibility issues.| | | | | | | | | | | | |
# | |Less errors in data found during daily audits| | | | | | | | | | | |
# |Less systems/badge access reactivation requests|6| | | | | | | | | | | |
# |CWM Team - Gigi|WT, CWM, SOW|Change Management|Change management plan (internal, client facing, supplier)|Creating a comprehensive change management plan is crucial for ensuring smooth transitions and effective implementation of improvements. Here are the key components you should include:| | | | | | | | |
# |1. Objectives and Goals| | | | | | | | | | | | |
# |•	Define clear objectives: What is the purpose of the change? What are the expected outcomes?| | | | | | | | | | | | |
# |•	Set measurable goals: Establish specific, measurable, achievable, relevant, and time-bound (SMART) goals.| | | | | | | | | | | | |
# |2. Change Impact Assessment| | | | | | | | | | | | |
# |•	Assess the impact: Evaluate how the change will affect the organization/client, including workflows, roles, and relationships.| | | | | | | | | | | | |
# |•	Identify stakeholders: Determine who will be affected by the change and how.| | | | | | | | | | | | |
# |3. Communication Plan| | | | | | | | | | | | |
# |•	Develop a communication strategy: Outline how information about the change will be communicated to all stakeholders.| | | | | | | | | | | | |
# |•	Ensure transparency: Provide regular updates and create channels for feedback.| | | | | | | | | | | | |
# |4. Change Readiness Assessment| | | | | | | | | | | | |
# |•	Evaluate readiness: Assess the organization's readiness for change, including the willingness and ability of employees to adapt.| | | | | | | | | | | | |
# |•	Identify barriers: Pinpoint potential obstacles and plan how to address them.| | | | | | | | | | | | |
# |5. Implementation Plan| | | | | | | | | | | | |
# |•	Detail the steps: Provide a step-by-step plan for implementing the change.| | | | | | | | | | | | |
# |•	Assign responsibilities: Define roles and responsibilities for each part of the implementation process.| | | | | | | | | | | | |
# |6. Training and Support| | | | | | | | | | | | |
# |•	Offer training: Provide necessary training to ensure everyone understands the new processes or systems.| | | | | | | | | | | | |
# |•	Support systems: Establish support mechanisms to help employees adapt to the change.| | | | | | | | | | | | |
# |7. Monitoring and Evaluation| | | | | | | | | | | | |
# |•	Track progress: Monitor the implementation process and measure progress against the goals.| | | | | | | | | | | | |
# |•	Evaluate outcomes: Assess the effectiveness of the change and make adjustments as needed.| | | | | | | | | | | | |
# |8. Feedback and Continuous Improvement| | | | | | | | | | | | |
# |•	Collect feedback: Gather feedback from stakeholders to understand their experiences and challenges.| | | | | | | | | | | | |
# |•	Iterate and improve: Use the feedback to make continuous improvements to the change process.| | | | | | | | | | | | |
# |9. Risk Management| | | | | | | | | | | | |
# |•	Identify risks: Determine potential risks associated with the change.| | | | | | | | | | | | |
# |•	Mitigation strategies: Develop strategies to mitigate these risks.| | | | | | | | | | | | |
# |10. Documentation| | | | | | | | | | | | |
# |•	Maintain records: Keep detailed documentation of the change process, including decisions, actions, and outcomes.| | | | | | | | | | | | |
# |11. Change Management Team| | | | | | | | | | | | |
# |•	Define roles: Identify who will be responsible for managing the change, including change champions and agents| | |Not tracked in TDW - unreportable by BI|Conducting a thorough post-implementation review is essential for identifying areas of improvement and ensuring future success. Here are some key items to review:| | | | | | | | |
# |1. Scope Management| | | | | | | | | | | | |
# |•	Scope Creep: Evaluate instances where the project scope expanded beyond initial plans. Identify the causes and implement strategies to prevent scope creep in future projects.| | | | | | | | | | | | |
# |•	Change Requests: Review all change requests and their impact on the project. Ensure a robust change control process is in place.| | | | | | | | | | | | |
# |2. Project Performance| | | | | | | | | | | | |
# |•	Timeline Adherence: Compare planned vs. actual timelines. Identify delays and their causes to improve scheduling accuracy.| | | | | | | | | | | | |
# |•	Budget Compliance: Assess whether the project stayed within budget. Analyze any cost overruns and find ways to manage finances better.| | | | | | | | | | | | |
# |3. Quality of Deliverables| | | | | | | | | | | | |
# |•	Quality Standards: Evaluate the quality of the final deliverables against predefined standards. Identify any gaps and areas for improvement.| | | | | | | | | | | | |
# |•	Customer Satisfaction: Gather feedback from clients and stakeholders to understand their satisfaction levels and areas needing enhancement.| | | | | | | | | | | | |
# |4. Risk Management| | | | | | | | | | | | |
# |•	Risk Identification: Review the risks identified during the project and how they were managed. Identify any unforeseen risks and improve risk assessment processes.| | | | | | | | | | | | |
# |•	Mitigation Strategies: Assess the effectiveness of risk mitigation strategies and refine them for future projects.| | | | | | | | | | | | |
# |5. Communication| | | | | | | | | | | | |
# |•	Communication Effectiveness: Evaluate the effectiveness of communication channels and strategies used during the project. Identify any communication breakdowns and improve transparency.| | | | | | | | | | | | |
# |•	Stakeholder Engagement: Review stakeholder engagement and involvement throughout the project. Ensure stakeholders were adequately informed and involved.| | | | | | | | | | | | |
# |6. Resource Management| | | | | | | | | | | | |
# |•	Resource Allocation: Assess how resources were allocated and utilized. Identify any inefficiencies and optimize resource management.| | | | | | | | | | | | |
# |•	Team Performance: Evaluate team performance and collaboration. Identify areas for improving teamwork and productivity.| | | | | | | | | | | | |
# |7. Lessons Learned| | | | | | | | | | | | |
# |•	Successes and Failures: Document what went well and what didn't. Use these insights to improve future project planning and execution.| | | | | | | | | | | | |
# |•	Continuous Improvement: Establish a process for continuous improvement based on lessons learned. Implement changes to enhance future project outcomes.| | | | | | | | | | | | |
# |8. Compliance and Documentation| | | | | | | | | | | | |
# |•	Compliance Review: Ensure all regulatory and contractual requirements were met. Identify any compliance issues and address them.| | | | | | | | | | | | |
# |•	Documentation Quality: Review the quality and completeness of project documentation. Ensure all necessary records are maintained for future reference.| |7| | | | | | | | | | |
# |Gigi|CWM|Client Inititives|Client Reduction in Force|If a client has a reduction in their FTEs, we need to check to see if any of the FTEs are approvers in the VMS.  Work with client sponsor and HR to understand who the replacement for the managers is being terminated. Follow the steps below to get started:| | | | | | | | |
# |•	Run user report to see if any of the managers are listed as approvers in the VMS.| | | | | | | | | | | | |
# |•	Run report on active workers and their manager/timesheet approver to see if any need replacement managers| | | | | | | | | | | | |
# |•	Run VMS report on pending approvals for reqs and timesheets to see if any need to move to replacement| | | | | | | | | | | | |
# |Once your client has advised you to do so, you need to remove access from the VMS for the manager/user.| | |Not tracked in TDW - unreportable by BI|If timesheet and /or requisition approvals are delayed, it could be that the approver is no longer employed by your client.  You should work with the +1 manager of the approver or contact the clients HR team.|You should see a reduced number of timesheets or requisitions pending approval.|8| | | | | | |
# |CWM Team - Gigi|WT, CWM, SOW|Client relationships|Stakeholders and business leaders (who is meeting and how often)|PMs should have a weekly meeting with the client sponsor to discuss any project updates and concerns.  Be sure to ask the sponsor if they have any feedback on the team and program. Include the Delivery Director in these meetings and the Engagement Director as optional.| | | | | | | | |
# | |The Engagement Directors should be meeting with the client regularly to discuss strategic opportunities/growth.  They will determine frequency. Delivery Directors should request that you be included in Engagement meetings so you can stay informed.  Delievery Directors and Engagement Directors should meet on a regular candence to ensure alignment.| |Not tracked in TDW - unreportable by BI| | |9| | | | | | |
# |Arch|WT, CWM, SOW|Client relationships|Being asked by client to do more than what our contract and MSP fee covers|Handling Client Requests Beyond Contractual and MSP Fee Scope| | | | | | | | |
# |To effectively manage situations where clients request services beyond the scope of the contract and MSP fee, consider the following approach:| | | | | | | | | | | | |
# |•	Understanding Contract Obligations:| | | | | | | | | | | | |
# |o	Ensure all program staff are well-versed in the program’s contract and obligations.| | | | | | | | | | | | |
# |o	This foundational understanding enables the team to navigate client requests within the agreed scope.| | | | | | | | | | | | |
# |•	Evaluate Services Offered:| | | | | | | | | | | | |
# |o	PMO should assess the services being provided by the program and utilize the TAPFIN Time report to understand the allocation of team members to specific roles.| | | | | | | | | | | | |
# |o	Measure the services offered against the MSP fee and rebates provided to ensure alignment and efficiency.| | | | | | | | | | | | |
# |•	Financial Awareness:| | | | | | | | | | | | |
# |o	All managers, Recruitment Managers (RMs), Program Managers (PMs), and Directors should have a clear understanding of the program’s SG&A and BLC.| | | | | | | | | | | | |
# |o	Directors should share the monthly reforecast numbers (Profit & Loss, not detailed tabs) with managers and Engagement teams, emphasizing collective responsibility for achieving these targets.| | | | | | | | | | | | |
# |•	Focus on BLC Management:| | | | | | | | | | | | |
# |o	Review and analyze information related to Managing your BLC to identify opportunities for optimization and improvement.| | | | | | | | | | | | |
# |•	Addressing Manual Task Requests:| | | | | | | | | | | | |
# |o	Understand that clients may request manual tasks from the PMO due to a lack of automation readiness. Examples include:| | | | | | | | | | | | |
# |	Manually entering requisitions from the VMS into their HR Applicant Tracking System (ATS) to enable data integration for new hires.| | | | | | | | | | | | |
# |o	Identify these requests and assess their alignment with TAPFIN’s core role of managing the MSP.| | | | | | | | | | | | |
# |•	Collaborative Problem-Solving:| | | | | | | | | | | | |
# |o	Use conversations with clients to explore automation opportunities and demonstrate how manual tasks can be streamlined.| | | | | | | | | | | | |
# |o	Focus on proactive solutions while ensuring the program remains within its contractual scope.| | | | | | | | | | | | |
# | |Work with engagement to ensure projects from clients are not chargable events.| |Not tracked in TDW - unreportable by BI| | |9| | | | | | |
# |Arch/Gigi|CWM|Contracts|Contract termination|•	When a program is terminating, it is essential to safeguard TAPFIN's assets and information. Internal SOPs should never be shared with the client or another MSP; instead, they must create their own training documents. Review contractual agreements to determine what data can be shared—such as supplier lists and worker data—and the required historical timeframe. If a client requests information beyond what should be provided, escalate the matter to your Delivery Director.| | | | | | | | |
# |•	When a supplier contract needs to be terminated, you need to understand if their agreement is with the client and we have a third party agreement to bind us, the client and the supplier, or if the agreement is directly between TAPFIN and the supplier.  Always include Vendor Enrollment when you are going to terminate a supplier agreeement and make sure you read the termination language in either the third party agreement, or the participtation agreement (direct with supplier).| | |Not tracked in TDW - unreportable by BI| | |10| | | | | | |
# |Kristin|WT, CWM, SOW|Contracts|Where are they? Who manages them?|*RP/PM should be aware of where all of the Contracts are located. These should all be in one place (IntelliReach, SharePoint, etc)| | | | | | | | |
# |*Best practice is to have either one person or one group of people have access to add, delete, etc. Not all should have this level.| | |Not tracked in TDW - unreportable by BI| |All team members should be aware of where contracts are stored and how to access them.|10| | | | | | |
# |Gigi|WT, CWM, SOW|Cost Saving|Cost Savings recommendations|Run cost savings reports per contract requirements (or obtain from BI).  Provide to client on a regular bases (at least quarterly) so they can see one of the many benefits of the program.|Complete analysis of VMS reports to project the cost savings for each initaitve and make recommendations benefical to client and TAPFIN.  Run the following VMS reports for potential of other costs savings initatives not already implemented:| | | | | | | |
# |•	OT/DT usage - Rate reduction| | | | | | | | | | | | |
# |•	Spend by Supplier - Volume discount| | | | | | | | | | | | |
# |•	Average tenure - Tenure discount| |Intermediate/Advanced:| | | | | | | | | | |
# |- Custom Analytics: TAPFIN Standard Cost Savings Workbook (tracks ratecard savings, OT savings, and payroll savings)| | | | | | | | | | | | |
# |- Insights Hub: Bill Rate Tool and Tenure Insight| | | | | | | | | | | | |
# |- Contact BI Analyst for additional reporting buildout|If cost savings is decreasing for your client and it is not because of a reduction in contingent labor use, you may need to investigate for a better savings initiative.This should also be researched after your client's implementation, especially in Gen 1 clients when you have more data than they did before.|Compare cost savings from previous quarters to most recent quarter after change|11| | | | | | | | | |
# |Kristin|CWM|Cost Saving|Tenure discount|•	The RP or PM must review the supplier contact to identify the tenure discounts applicable to the Program.| | | | | | | | |
# |•	Determine who within the Program is responsible for tracking and enforcing tenure (i.e., RP, ROC)| | | | | | | | | | | | |
# |•	To apply the tenure discount to the billing rate, a work order revision is required. For all monetary changes to a work order, the RP must ensure detailed comments are added to the comment section for tracking purposes.| | | | | | | | | | | | |
# | |*You can utlize the ROC to track and process tenure discounts.| |Intermediate/Advanced:| | | | | | | | | |
# |- Contact BI Analyst for possible reporting buildout. Note: Not all VMS tools are built to allow reporting on tenure discounts and those that have the possibility can only report on an estimation through the TDW.| |With the tracking of tenure, you are able to report on worker tenure and cost savings.|11| | | | | | | | | |
# |Kristin|CWM|CW Management|Medical Accommodations|•	Your Client should utilize a Medical Accommodation Intake form, which is to be completed by the supplier to outline and request medical accommodations for their contingent worker (CW). Collaboration with the Client Occupational Health office is essential to ensure accurate and complete documentation| | | | | | | | |
# |•	Key information to be captured includes:| | | | | | | | | | | | |
# |o	Whether the doctor's note includes a diagnosis or nature of the medical condition (Y/N). Note: The supplier must maintain the confidentiality of the diagnosis/medical condition and should not disclose the details.| | | | | | | | | | | | |
# |o	Whether the accommodation request or work restrictions impact the essential job functions of the CW assignment.| | | | | | | | | | | | |
# |o	A summary of the accommodation request or work restrictions.| | | | | | | | | | | | |
# |o	The start date of the accommodation request or work restrictions.| | | | | | | | | | | | |
# |o	The anticipated duration of the accommodation request or work restrictions.| | | | | | | | | | | | |
# |o	Whether the restrictions are currently being accommodated (Y/N).| | | | | | | | | | | | |
# |o	Whether a job analysis has been completed if the essential job functions are impacted.| | | | | | | | | | | | |
# | |•	If a medical accommodation request is rejected and the site confirms that they cannot accommodate it, the Client should make every effort to identify a temporary role for the contingent worker (CW).| | | | | | | | | | | |
# |•	If no suitable role is available, TAPFIN must initiate an Employee Relations ticket with the Client's Employee Relations team. The team's decision will determine whether the accommodation can be made or if the assignment will come to an end.| | | | | | | | | | | | |
# | | |Not tracked in TDW - unreportable by BI|If you are receiving information regarding medical accommodations, you should follow a designated process each time.  This should be well documented as well.|Are medical accommdations being well tracked, well documented? This process is successful if well communicated to Supplier partners and reviewed with the Client's Occupational Health team.|12| | | | | | | |
# |Kristin|CWM|CW Management|Reasonable Suspicion|•	The Client must notify TAPFIN if they suspect a worker is under the influence of drugs or alcohol.| | | | | | | | |
# |•	If witnesses are present, the RP (Resource Professional) or Manager should collect their statements.| | | | | | | | | | | | |
# |•	If the site has an onsite health or nurse team, the worker should be escorted there for evaluation.| | | | | | | | | | | | |
# |•	TAPFIN should inform the worker's agency about the situation.| | | | | | | | | | | | |
# |•	The worker's agency representative is responsible for making the final decision regarding for cause drug testing and coordinating the testing location with the worker, if applicable.| | | | | | | | | | | | |
# | |•	If a worker is visibly under the influence and unfit to operate a vehicle, the Client must arrange alternative transportation, such as an Uber, to ensure the worker is safely removed from the site.| |If your program's end reasons include a Reasonable Suspicion or similarly worded end reason, utilize the negative attrition reports in Talent Loupe and Insights Hub| | |12| | | | | | |
# |Kristin|CWM|CW Management|Injury Management|For workers' compensation purposes, all incidents and injuries must be reported, regardless of the severity of the accident. The following parties are involved in the process: TAPFIN RP, Client Manager, Client Occupational Health Nurse (OHN), Client Environmental Health and Safety (EHS), and the supplier.| | | | | | | | |
# |1.	The Manager must notify the TAPFIN RP and OHN of any injury or incident.| | | | | | | | | | | | |
# |2.	TAPFIN should verify that the OHN is already informed and involved.| | | | | | | | | | | | |
# |3.	The OHN will assess the worker, provide first aid as needed, and/or refer the worker to external treatment if required.| | | | | | | | | | | | |
# |4.	TAPFIN must inform the supplier by sharing the OHN's evaluation.| | | | | | | | | | | | |
# |5.	The supplier is responsible for following up with the worker. In the case of a serious injury, the supplier must collect any necessary restrictions and/or a doctor’s note for the worker's return to work.| | | | | | | | | | | | |
# |If the injury is work-related:| | | | | | | | | | | | |
# |•	Workers' compensation forms (e.g., M-1 and/or Activity Status Report) must be shared with Occupational Health (OH).| | | | | | | | | | | | |
# |•	The Supervisor, Manager, and Business Human Resources (BHR) team must be informed of critical information (e.g., work restrictions, days out, estimated duration of restrictions or time off) and consulted to determine if accommodations can be safely made.| | | | | | | | | | | | |
# |•	If a follow-up appointment is scheduled, updated forms must be submitted within 24 hours of the appointment.| | | | | | | | | | | | |
# |•	If a follow-up appointment is necessary but not yet scheduled (e.g., all work-related incidents require discharge clearance) or if the appointment is missed, the agency must be contacted to request that the appointment is (re)scheduled, and updated information must be provided within 24 hours of notification| | | | | | | | | | | | |
# |If the injury is not work-related:| | | | | | | | | | | | |
# |•	Forms do not need to be shared with Occupational Health.| | | | | | | | | | | | |
# |•	The Supervisor, Manager, and Occupational Health must be informed of critical information (e.g., work restrictions, days out, estimated duration of restrictions or time off) and consulted to determine if accommodations can be safely made| | | | | | | | | | | | |
# |•	If a follow-up appointment is scheduled or deemed necessary, updated information must be submitted within 24 hours of the appointment.| | | | | | | | | | | | |
# |•	If a follow-up appointment is necessary but not yet scheduled (e.g., restrictions requiring clearance for return-to-work) or if the appointment is missed, the agency must be contacted to request that the appointment is (re)scheduled, and updated information must be provided within 24 hours of notification| | | | | | | | | | | | |
# | |•	If a worker requires a medical accommodation, a Medical Accommodation Form should be created in collaboration with your Client. The supplier must complete the form, which will then be reviewed by the Client. For further details, refer to the Medical Accommodation section under CW Management in this document.| |Not tracked in TDW - unreportable by BI|When accommodation requests arrise, there should be a set process in place to review, assign and complete the request.| |12| | | | | | |
# |Gigi|CWM, SOW|Data Integrity|Reminders and Dashboards|Review VMS Dashboards daily to correct any errors in data as well as work any approaching/missed deadlines.|PM should audit VMS Dashboards daily to ensure errors and aged items are resolved.| | | | | | | |
# |PM should ensure the right items are listed on the dashboard for team.  This list could change as the program matures.| | | | | | | | | | | | |
# |•	End date approaching| | | | | | | | | | | | |
# |•	Expired workers| | | | | | | | | | | | |
# |•	Non-compliant workers| | | | | | | | | | | | |
# |•	Extensions to be processed| | | | | | | | | | | | |
# |•	Reqs to be approved| | | | | | | | | | | | |
# |•	Reqs approaching/past TTF SLA| | | | | | | | | | | | |
# |•	Any others that your VMS can capture| |Not tracked in TDW - unreportable by BI|If data is not accurate in the VMS or the program team is being reactive instead of proactive, you may need to review what you have listed on the VMS Dashboard for the PMO.|Dashboard numbers reduced in each category and team becomes more proacitve than reactive.|13| | | | | | | |
# |Kristin|WT, CWM, SOW|Data Integrity|Workers who work at multiple locations or for mulitple managers, are they assigned to the correct cost center, Manager, Site, etc. (manager communications to the PMO)|•	The RP (Resource Professional) or PM (Program Manager) should configure an automated VMS report to be sent to each Client site on a weekly basis.| | | | | | | | |
# |•	The Client must review this report to verify that workers are still assigned to their designated site and are reporting to the manager listed in the VMS.| | | | | | | | | | | | |
# |•	The Client should notify the appropriate party whenever updates to a manager or site are required in the VMS. This is typically the Resource Professional.| | | | | | | | | | | | |
# |•	It is recommended to provide the Client with a standardized template to use when requesting changes to a worker's contact information.| | | | | | | | | | | | |
# |•	Ideally, the report format should resemble the upload file used to make updates in the VMS. This ensures a quicker turnaround time for processing changes.| | | | | | | | | | | | |
# | |•	The PM (Program Manager) should escalate the issue to the program sponsor if the designated site or manager consistently provides reactive updates rather than proactive ones.| | | | | | | | | | | |
# |o	For example, if a manager reports, John Smith moved to a different site and shift two weeks ago, this represents a delay in communication.| | | | | | | | | | | | |
# |•	TAPFIN must receive such information in real time to maintain accurate data, particularly when worker pay rates are impacted by shift differentials| | | | | | | | | | | | |
# | | | |If discrepancies are identified in contractor data (e.g., site, manager, cost center), it is advisable to establish a regular review cadence with the Client. The Client must promptly share any updates with TAPFIN to ensure timely adjustments. TAPFIN will then update the VMS accordingly to maintain accurate records.|Data accuracy will meaure success.|13| | | | | | | |
# |Arch|CWM|Diversity Solutions|tier 1 vs Tier 2 (paying suppliers directly vs tapfin) Using Consciously Unbiased|All suppliers for CWM and SOW should be tracked by the vendor enrollment team during onboarding.| | | | | |14| | |
# |Arch|WT, CWM, SOW|Financial Planning|Managing your BLC|All managers, RMs and PMs and Directors should be aware of the programs SG&A and BLC. All directors should be sharing the monthly reforecast numbers with the managers and Engagement. (Just the PNL not the tabs). This is because everyone has a responsibility in helping this number. The RMs should be looking at open reqs and asking about upcoming volume to understand how to best staff the teams. The PMs need to be having demand conversations with their business leaders and sharing with the RM and Director (who will be adding this to the budget file). The PM should also be asking the RPs if there are unexpected ends coming up. This is a good conversation that PMs and Directors and Engagement can be asking program sponsors and business leaders at their clients. The most proactive programs have these conversations built into their client conversations and then have an internal PMO meeting at least twice a month to talk through any patterns. THis will allow you to stay on top of changes. The smaller the client, the more impactful just a few starts or ends may have. If you have a large client then you need more ends or starts to move the needle, but you can still know exactly what is normal for your client. For this you need to look at Talent Loupe. You will need to create a headcount report as a whole as well as filter and save a report for each labor category you enter heads for in your budget. This will tell you exactly per week how many new starts and ends you have. Look for patterns in labor categories or business units. Share with all RPs, Managers and Directors.| | | | | | | | |
# |When it comes to revenue, again it is most helpful and proactive if everyone from your Global Director to country leads, to managers to RPs or PPs are having these kinds of conversations with managers or business leads. As a good rule of thumb, if you are forecasting any significant starts or ends, you need to forecast a matching increase or decrease in SG&A.|Other ways to manage your BLC- is to evaluate WHY you have the number of PMO members that you do. For example, are you top heavy with too much Director or Manager time allocated against this client? Or do you have more RPs than a normal program should have. You should evaluate if you are a brand new launched program so it makes sense you might have more PMO members at launch since everything is new. If you are not a new program look at how many manual or additonal processes your team does compared to others. Also look at your MSP fee or rebates. Sometimes older accounts have cut their MSP fees or offered more rebates, which will always cut into your revenue. THe Director should reach out to their MD and other Directors to compare their SG&A hours from finance and TAPFIN TIME. If you have more team members for the same amount of revenue, or if your fees are smaller or rebates are higher, this is a possible root cause fo your BLS issues. Your options include talking to your VP about renegotiating your MSP fee, or rebates. OR you can look at what manual processes you can no longer afford to run for the client.| |Not tracked in TDW - unreportable by BI| | |15| | | | | | |
# |Arch|WT, CWM, SOW|Financial Planning|How to forecast|To effectively manage your budget forecasting and planning, follow these steps:| | | | | | | | |
# |•	Run Headcount Reports: Extract headcount data from the VMS and pivot the results by labor categories in your budget file.| | | | | | | | | | | | |
# |•	Run Spend Reports: Retrieve spend reports from the VMS and pivot the data by labor categories in your budget file.| | | | | | | | | | | | |
# |•	Historical Analysis: Generate reports covering the past 4–5 weeks, aligning with your most recent budget reforecast.| | | | | | | | | | | | |
# |•	Maintain a Running Report: Continuously track your spend and headcount pivots. Add the latest 4 weeks of data to calculate the monthly average.| | | | | | | | | | | | |
# |•	Future Projections: Assess open requisitions and engage with your PMs and client sponsors to gather insights on upcoming hiring initiatives, layoffs, freezes, and other factors that may influence forecasts.| | | | | | | | | | | | |
# |•	Proactive Check-Ins: Incorporate these reporting and forecasting activities into regular weekly check-ins with your PMO and client. This proactive approach ensures you stay informed and ahead of potential challenges.| | | | | | | | | | | | |
# | |* VMS reports on New Reqs, Attrition| | | | |15| | | | | | |
# |Kristin|WT, CWM, SOW|Gemini Tickets|Internal|•	New users must be added to Gemini, and their access to projects must be granted accordingly.| | | | | | | | |
# |•	For Fieldglass accounts, if a request is made to add a new user to Gemini, the following project options are available. Users should specify the project they require access to:| | | | | | | | | | | | |
# |•	Project Options for Fieldglass:| | | | | | | | | | | | |
# |o	VMS Escalations Analysts| | | | | | | | | | | | |
# |o	Verizon Escalations/Analysts (specific to Verizon)| | | | | | | | | | | | |
# |•	Additional Project Options:| | | | | | | | | | | | |
# |o	Intellireach Help| | | | | | | | | | | | |
# |o	BI-Help| | | | | | | | | | | | |
# |o	RPO IR Support| | | | | | | | | | | | |
# |o	Standard projects are typically designated for PM level roles and above.| | | | | | | | | | | | |
# |•	Other available projects:| | | | | | | | | | | | |
# |o	BI-IR-DEMO| | | | | | | | | | | | |
# |o	Help-VMS| | | | | | | | | | | | |
# |o	SUP-INS| | | | | | | | | | | | |
# |o	IR-HELP| | | | | | | | | | | | |
# | | | |Not tracked in TDW - unreportable by BI| | |16| | | | | | |
# |Kristin|WT, CWM, SOW|Gemini Tickets|Client|* Is your Client set up to utilize Gemini for tickets? I.e. the Abbott account does have Client access to Gemini.  The below ticket types can be utilized when sending a ticket through Gemini to an Abbott team:| | | | | | | | |
# |•	Rate Exception Request| | | | | | | | | | | | |
# |•	Skill Code Request| | | | | | | | | | | | |
# |•	Tenure Exception| | | | | | | | | | | | |
# |•	Flagged background exception approval| | | | | | | | | | | | |
# |•	Pending background exception approval|A TAPFIN Team member (normally PM, but  RPs do have some accesses) enters a ticket into Fieldglass for the Client and the issue/task is managed via comments through the Gemini ticket.| | | | | | | | | | | |
# |•	Some clients with access to Gemini use the system as their primary communication platform, not just for resolving issues.| | | | | | | | | | | | |
# |•	Instead of relying on an email inbox, they utilize Gemini for all forms of communication.| | | | | | | | | | | | |
# | | |Not tracked in TDW - unreportable by BI| | |16| | | | | | | |
# |Arch|CWM|Headcount|Headcount - what does the pattern tell you|Leveraging Talent Loupe and Insights Hub| | | | | | | | |
# |Program Managers (PMs) should consistently use Talent Loupe and Insights Hub to monitor headcount data, categorized by universal filters such as region, country, labor category, manager, business unit, initiative (if applicable), and the top 10 titles. These tools provide weekly insights into the number of starts and ends, enabling PMs to assess their program’s volume and evaluate the workload of their Recruitment Professionals (RPs).| | | | | | | | | | | | |
# |Key advantages include:| | | | | | | | | | | | |
# |•	Supplier Engagement: Use the data to facilitate discussions with suppliers, prospective partners, or those being mentored, helping them prepare for future requirements.| | | | | | | | | | | | |
# |•	Predictive Hiring Patterns: Analyze trends to identify where and what roles the client is hiring, uncovering potential predictive patterns.| | | | | | | | | | | | |
# |•	Demand Forecasting: Utilize the demand forecast feature in Insights Hub. Collaborate with the BI Analyst to maximize its capabilities for more accurate planning.| | | | | | | | | | | | |
# |A proactive PM filters headcount data by labor category and shares insights with their Recruitment Managers (RMs), RPs, and suppliers, fostering better collaboration and informed decision-making.| | | | | | | | | | | | |
# | |Proactive Forecasting Practices| | | | | | | | | | | |
# ...
# |•	Seasonal Trends: Does this issue occur at specific times of the year? Identifying seasonal patterns can help develop targeted solutions.| | | | | | | | | | | | |
# | | | | | | | | | | | | | |
# |By analyzing approval trends and addressing potential barriers, PMs can enhance efficiency, accountability, and overall program performance.| | | | | | | | | | | | |
# | | | | | | | | | | | | | |
# |Consider: Should the sponsor be contacted to implement an auto-approval policy if timesheets aren't approved within a certain period of time?| |Not tracked in TDW - unreportable by BI|Strategies for Improving Timesheet Approval Efficiency| | | | | | | | | |
# |1. Addressing Consistent Approval Delays| | | | | | | | | | | | |
# |•	Automate Reminders: Implement automated notifications prompting managers to approve timesheets before deadlines.| | | | | | | | | | | | |
# |•	Set Clear Deadlines: Re-establish and communicate firm deadlines for timely approvals.| | | | | | | | | | | | |
# |2. Resolving Manager-Specific Delays| | | | | | | | | | | | |
# |•	Provide Training: Offer training sessions to educate managers on the importance of timely approvals and ways to streamline the process.| | | | | | | | | | | | |
# |•	Assign Delegates: Enable managers to delegate timesheet approval responsibilities to other team members when unavailable.| | | | | | | | | | | | |
# |3. Addressing System-Related Issues| | | | | | | | | | | | |
# |•	Enhance System Usability: Improve the VMS interface to ensure timesheet approval is intuitive and user-friendly.| | | | | | | | | | | | |
# |•	Offer Technical Support: Provide assistance to resolve any system-related challenges contributing to approval delays.| | | | | | | | | | | | |
# |4. Overcoming Process Challenges| | | | | | | | | | | | |
# |•	Simplify Procedures: Review and optimize the timesheet submission and approval processes to minimize complexity.| | | | | | | | | | | | |
# |•	Enhance Communication: Strengthen engagement between contingent workers and managers to facilitate timely submissions and approvals.| | | | | | | | | | | | |
# |Taking a proactive approach to timesheet management ensures smoother operations, reduces bottlenecks, and enhances overall program efficiency.| | | | | | | | | | | | |
# | | |32| | | | | | | | | | |
# |Gigi|CWM|Timesheet Management|Audit of timesheets (is OT entered when working <40 hours or <8/day in CA)|1) Run Monthly Compliance Reports:| | | | | | | | |
# |Generate Reports: Create reports that highlight overtime hours recorded and check for compliance with state laws.| | | | | | | | | | | | |
# |Analyze Data: Identify any instances of non-compliance.| | | | | | | | | | | | |
# | | | | | | | | | | | | | |
# |2) Evaluate Findings:| | | | | | | | | | | | |
# |Spot Issues: Determine the root causes of non-compliance.| | | | | | | | | | | | |
# |Gather Feedback: Collect feedback from managers and workers.| | | | | | | | | | | | |
# |Implement Solutions:| | | | | | | | | | | | |
# | | | | | | | | | | | | | |
# |3) Provide Training: Offer training sessions on proper timesheet recording and compliance.| | | | | | | | | | | | |
# | |Enhance Systems: Improve the VMS interface if errors are consistent across the board and training does not solve.|Look for trends, are the same supplier workers not submitting time correctly, force suppliers to retrain workers and confirm completion.|Regularly utilize Insights Hub and the integrated filters to spot issues. Contact your BI analyst for more detailed reporting if necessary|1.	If Data Shows Non-Compliance:| | | | | | | | |
# |•	Implement Training: Provide training for managers and workers on state-specific overtime laws and proper timesheet recording.| | | | | | | | | | | | |
# |•	Enhance Systems: Upgrade your VMS to include automated compliance checks for overtime recording.| | | | | | | | | | | | |
# |2.	If Errors Are Found:| | | | | | | | | | | | |
# |•	Improve Data Entry Processes: Simplify and standardize timesheet entry processes to reduce errors.| | | | | | | | | | | | |
# |3.	If Patterns of Non-Compliance Are Identified:| | | | | | | | | | | | |
# |•	Investigate Causes: Conduct a thorough investigation to understand the root causes of non-compliance.| | | | | | | | | | | | |
# |4.	If System Issues Are Detected:| | | | | | | | | | | | |
# |•	Enhance System Usability: Improve the VMS interface to make timesheet recording and auditing easier and more intuitive.| |32| | | | | | | | | | |
# |Kristin|CWM|Timesheet Management|Internal: Econometrix, Manpower staffing hours|At TAPFIN, two distinct time entry portals must be utilized:| | | | | | | | |
# |•	Econometrix: This portal is used to track weekly employee (non-temp) activities. It records details such as which clients your time was allocated to and the specific activities performed.| | | | | | | | | | | | |
# |•	Manpower Staffing Hours: This portal is tied to compensation and covers a two-week period per timesheet. It also tracks your Paid Time Off (PTO) balance.| | | | | | | | | | | | |
# | |For questions regarding Econometrix, training materials can be accessed in the Help section of the site, under Documents. If you encounter login issues, please contact TAPFINtime@tapfin.com| | | | | | | | | | | |
# |For issues related to Manpower Staffing Hours, you can reach out to:| | | | | | | | | | | | |
# |•	Manpower Helpdesk: 1-800-888-9925| | | | | | | | | | | | |
# |•	Experis Service Desk: 1-877-342-9515| | | | | | | | | | | | |
# | | |Not tracked in TDW - unreportable by BI| |Ensuring time is accurately entered and allocated to the correct categories—such as PTO, YOU Day, and hours worked—will result in proper compensation being reflected in your paycheck. Additionally, your PTO balance will be tracked accurately.|32| | | | | | | |
# |Arch|WT, CWM, SOW|Training|Internal training plan for new team members|Onboarding Best Practices for New Team Members| | | | | | | | |
# |Before hiring new team members, managers should visit the TAPFIN Start Strong site to review essential onboarding documents. Managers are responsible for ensuring a smooth transition by completing the following tasks:| | | | | | | | | | | | |
# |•	Introductions: Facilitate introductions between the new team member and key business leaders they will be collaborating with.| | | | | | | | | | | | |
# |•	Platform Access: Ensure the worker is added to all necessary Teams channels or other relevant collaboration sites.| | | | | | | | | | | | |
# |•	IntelliReach Access: Provide access to IntelliReach as needed.| | | | | | | | | | | | |
# |•	Meeting Integration: Add the new worker to upcoming meetings and coordinate with meeting owners to include them in relevant invite lists.| | | | | | | | | | | | |
# |Training Approach: Balancing Practical Experience & Education| | | | | | | | | | | | |
# |Effective training should combine on-the-job experience with comprehensive skills development. If the manager only trains the worker on client-specific tasks or daily operations, the worker may lack a broader understanding and the ability to make informed decisions independently.| | | | | | | | | | | | |
# |Proactive Check-ins for Effective Onboarding| | | | | | | | | | | | |
# |If training involves multiple team members throughout the day, the hiring manager should still take an active role by:| | | | | | | | | | | | |
# |•	Morning Check-ins: Touching base at the start of the day to ensure expectations and objectives are clear.| | | | | | | | | | | | |
# |•	End-of-Day Check-ins: Following up in the evening to assess the worker’s experience, address any concerns, and answer questions.| | | | | | | | | | | | |
# |Maintaining a proactive approach to onboarding fosters engagement, accelerates integration, and empowers new hires to contribute effectively.| | | | | | | | | | | | |
# | |Structured Onboarding & Training Documentation| | | | | | | | | | | |
# |An effective team maintains documented Standard Operating Procedures (SOPs) for onboarding and structured training schedules to ensure a smooth transition for new workers.| | | | | | | | | | | | |
# |Client-Specific Knowledge Base| | | | | | | | | | | | |
# |If a worker is assigned to a specific client, the manager should ensure they have access to a OneNote document containing:| | | | | | | | | | | | |
# |•	A client overview (generated using Copilot)| | | | | | | | | | | | |
# |•	Information on business units| | | | | | | | | | | | |
# |•	A clear outline of the client’s goals and objectives| | | | | | | | | | | | |
# |Manager-Led Review for Strategic Alignment| | | | | | | | | | | | |
# |To provide deeper insight into TAPFIN’s role and value within the client’s program, managers should review key materials with the worker, including:| | | | | | | | | | | | |
# |•	Global Talent Operations Model (GTOM)| | | | | | | | | | | | |
# |•	Program Management Plan (PMP)| | | | | | | | | | | | |
# |•	Latest Quarterly Business Reviews (QBRs)| | | | | | | | | | | | |
# |This structured approach ensures that new team members not only understand TAPFIN’s contributions but also recognize how they can align their responsibilities to support client success.| | | | | | | | | | | | |
# | | |Not tracked in TDW - unreportable by BI| | |33| | | | | | | |
# |Kristin|WT, CWM, SOW|Training|Client Training - managers|•	The RP should review the capabilities of the Vendor Management System (VMS) with the manager, focusing on the key modules the manager will primarily utilize.| | | | | | | | |
# |•	The RP should also review the program guidelines. If no guidelines exist, create a PowerPoint presentation (PPT) to serve as a resource for new managers.| | | | | | | | | | | | |
# |•	The PM should conduct co-employment training with the client annually unless the client requests a different schedule.| | | | | | | | | | | | |
# |•	The RP/PM should share additional tools available to the hiring manager beyond the VMS. Tip: Ensure there is a clear and concise document listing these tools for easy reference.| | | | | | | | | | | | |
# |•	The PM should coordinate client training with a Business Intelligence (BI) Analyst for a walkthrough of Intellireach, Talentloupe, and the Insights Hub.| | | | | | | | | | | | |
# | |•	Host 1:1 VMS and/or Program Training| | | | | | | | | | | |
# |•	Tailor training to the manager's specific needs by involving additional TAPFIN team members who can provide relevant expertise.| | | | | | | | | | | | |
# |o	For example, if a manager has a strong analytical focus and requires complex reports, consider including your Analytics team in the training to address this aspect.| | | | | | | | | | | | |
# | | |Coordinate with BI analyst to walk thru Talent Loupe or for questions around Insights Hub. Expectations for Insights Hub are that the PM can walk thru functionality of the dashboards with the client and refer to the BI analyst via Gemini ticket for data validation issues, feedback for improvements, or  a deeper dive into data|•	Discuss VMS capabilities with the manager.| | | | | | | | | |
# |•	Discuss Program guidelines.| | | | | | | | | | | | |
# |•	Coemployment training| | | | | | | | | | | | |
# |•	PM to schedule Client training with BI Analyst for Intellireach/Talentloupe/Insights hub walkthrough| | | | | | | | | | | | |
# | |•	The hiring manager should become independent after receiving training.|33| | | | | | | | | | |
# |CWM Team - Gigi|WT, CWM, SOW|VMS|VMS Evaluation, evolution, new functionality, enhancements, down-time, system performance issues|•	Ensure you are receiving updates from your VMS on new functionality and enhancements to see if they should be implemented and utilized in your program.| | | | | | | | |
# |•	Ensure you have a Business Continuity Plan from your VMS to ensure the system will be operatable and you know the correct people to contact in the event of an emergency.| | | | | | | | | | | | |
# |•	Ensure you are on the TAPFIN distribution list for notifications of outages.| | | | | | | | | | | | |
# |•	Ensure you have a communication plan for your client in the event of an outage.| | | | | | | | | | | | |
# |•	Enter Gemini ticket to obtain your VMS’s system up-time.| | | | | | | | | | | | |
# |•	Understand the processing time for VMS tickets and follow up accordingly.| | |Not tracked in TDW - unreportable by BI| | |34| | | | | | |
# |CWM Team - Gigi|WT, CWM, SOW|VMS|Review of help guides and updates|•	Help guides stored in the VMS should be reviewed quarterly to ensure they are up-to-date and include the latest screenshot and functionality of the VMS.|•	Your VMS should have a help section/reference library where you can store SOPs and help guides for managers and suppliers.| |Not tracked in TDW - unreportable by BI|If you are receiving a large amount of emails asking the PMO how to do something in the VMS, assist the person by showing them where the job aids are located and walk them through the process.|Updated job aids should result in lower inquiries to the PMO on VMS functionality.|34| | |
# |Kristin|WT, CWM, SOW|VMS|Test environments|•	Test environments provide a valuable opportunity to preview potential changes to the Vendor Management System (VMS) before implementing them in a live setting.| | | | | | | | |
# |•	These environments are typically utilized by Program Managers (PMs) and higher-level roles.| | | | | | | | | | | | |
# |•	To gain access to a VMS test environment, reach out to your TAPFIN VMS Analyst.| | |Not tracked in TDW - unreportable by BI|•	If you have an action you would like to perform in the VMS to understand an outcome, a test environment is what should be utilized.|•	Within a test environment you should solution challenges/questions/issues within the VMS functionality without worry of interrupting the production/live site.|34| | | | | | |
# |Kristin|CWM|Reporting|Program Dashboards|•	Program Dashboards can be created by your TAPFIN BI Analyst in Intellireach. As of April 2025, there is a new module in Intellireach with prebuild reports and dashboards called “Insights Hub”.  This is available to select Clients at this time but will expand to all TAPFIN Programs in the future.| | | | | | | | |
# | | | | | | | | | | | | | |
# |Suggested elements to include in a program dashboard:| | | | | | | | | | | | |
# |o	Year-to-Date (YTD) activity, such as total management spend, total spend, and total hires.| | | | | | | | | | | | |
# |o	A bar graph displaying the monthly spend trend.| | | | | | | | | | | | |
# |o	A bar graph illustrating the monthly headcount trend.| | | | | | | | | | | | |
# |o	Current month activity (if dashboards are provided monthly), including:| | | | | | | | | | | | |
# |	Monthly spend, turnover, starts and ends.| | | | | | | | | | | | |
# |	Top positions or job titles currently in use.| | | | | | | | | | | | |
# |	Offer-to-Fill (OTF) percentage.| | | | | | | | | | | | |
# |	Time-to-Fill (TTF).| | | | | | | | | | | | |
# |o	Cost savings achieved to date or for the year.| | | | | | | | | | | | |
# |•	To request Program Dashboards, submit a BI-Help ticket in Gemini to initiate the creation of a program dashboard.| | | | | | | | | | | | |
# | |•	Program dashboards provide valuable insights into your program's performance.| | | | | | | | | | | |
# |•	Sharing this information with the client during monthly meetings can highlight key performance metrics, such as Time-to-Fill (TTF), headcount, most frequently used job titles, attrition rates, and more.| | | | | | | | | | | | |
# | | |Basic: Insights Hub reporting| | | | | | | | | | |
# | | | | | | | | | | | | | |
# |Intermediate: Contact BI analyst to tailor a program dashboard to your specific needs|If you're looking for a visual representation of data to share with your Client, the Program Dashboards is one great way to share information.|•	Success if your Client having visibility and understanding of YTD activity, spend trends, headcount trends, monthly activity and cost savings (among other topics)|24| | | | | | | | | |
# | | | | | | | | | | | |Lori|How is this going to be rolled out?  Suggest IntelliReach since already used by the PMO teams.  Also a Q&A format could be easier to digest.  Will you  have a 'last updated' and how will you keep it updated.|

# %%
node_parser = MarkdownElementNodeParser(llm=llm_gpt4o_mini, num_workers=4)

# %%
nodes = node_parser.get_nodes_from_documents(documents[:2])
# Out:
# 1it [00:00, 7061.12it/s]
# 1it [00:00, 165.70it/s]

# %%
base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
len(nodes), len(base_nodes), len(objects)
# Out:
# (6, 2, 2)

# %%
recursive_index = VectorStoreIndex(nodes=base_nodes + objects, llm=llm_gpt4o_mini)


recursive_query_engine_gpt4o_mini = recursive_index.as_query_engine(
    similarity_top_k=5, llm=llm_gpt4o_mini
)

# %%
query = "Can you show me the  initial list of stpes to follow  for 'Cost Center Changes'?  "

#response_recursive_o1 = recursive_query_engine_o1.query(query)
#response_recursive_o1_preview = recursive_query_engine_o1_preview.query(query)
response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# 1. Enable the ROC (Recruiting Operations Center) to assist with routine cost center updates.
# 2. Ensure the cost center change is reflected across all relevant fields:
#    - Assignment details
#    - Job requisition (determine if a new requisition or different approvers are needed)
#    - Update the manager and business unit if applicable.
# 3. Run a VMS report post-update to confirm all changes were applied correctly.

# %%
print(response_recursive_gpt4o_mini.source_nodes[1].get_content())
# Out:
# This table outlines various program issues and metrics related to service level agreements (SLA), integration challenges, and activity tracking, along with potential solutions and metrics for measuring the success of those solutions.,
# with the following table title:
# SLA/KPI, Integration, Activity metrics, Performance, etc…,
# with the following columns:
# - WT, CWM, SOW: Categories related to the project.
# - Issue/Metric Type (larger category if applicable): Types of issues or metrics being addressed.
# - Data Points to measure: Specific metrics or data points relevant to the issues.
# - Possible Solutions: Proposed solutions for the identified issues.
# - Data Points to measure  Solution success: Metrics to evaluate the effectiveness of the solutions.
#
# |Name|WT, CWM, SOW|Issue/Metric Type (larger category if applicable)| | .1|
# |---|---|---|---|---|
# |SLA/KPI, Integration, Activity metrics, Performance, etc…|Program Issue or Metrics|Data Points to measure|Possible Solutions|Data Points to measure  Solution success|
# | |SOW|SLA/KPI|time to project promotion (add definitions)| |
# | |WT, CWM, SOW|Integration issues|invoice feeds failing from VMS to procurement tool| |
# | | |Integration issues|payload issues| |
# | |SOW|Activity metrics|tracking milestones| |

# %%
query = "what are reports we can use for Cost Center Changes "


response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# For Cost Center Changes, you can utilize the following reports:
#
# 1. **VMS Report**: Run a report post-update to confirm all changes were applied correctly.
# 2. **Custom Analytics**: The TAPFIN Interactive Dashboard can provide relevant backup data that could assist with project auditing purposes.
# 3. **Billing and Invoicing Reports**: If there are billing and invoicing errors, checking the cost centers and business units of the worker can help identify issues.
#
# These reports will help ensure that all necessary updates and changes are accurately reflected and monitored.

# %%
query = "Can you show me the  initial list of steps for Supplier termination "


response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# 1. Review the specific program supplier contract to determine if a 3-strikes rule applies to suppliers.
# 2. Evaluate the past Corrective Action Reports (CARs) issued to the supplier to ensure there is substantial evidence indicating that the supplier is no longer a valuable contributor to the program.
# 3. Consider terminating the supplier's involvement in a specific category rather than completely removing them from the program.
# 4. Determine if the supplier has active headcount, as this may impact the timing of their deactivation in the Vendor Management System (VMS).
# 5. Conduct a supplier meeting to facilitate official termination communication and processes.
# 6. Verify whether data is skewed, ensuring that the supplier is categorized correctly in the VMS.
# 7. Track close reasons to assess whether the supplier is eligible to rejoin the program in the future.

# %%
query = "Can you show me the  initial list of steps for worker promotions "


response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# 1. When a worker is promoted to a new role, the TAPFIN Resource Professional (RP) is responsible for communicating the promotion as a job offer to the supplier.
# 2. The supplier must confirm whether the worker accepts or declines the promotion.
# 3. Once the promotion is accepted, the TAPFIN RP must create a new job posting and work order aligned with the new job title.
# 4. If a tenure discount is already applied to the worker's current work order, this discount will automatically carry over to their new job title.
# 5. The TAPFIN RP should ensure that comprehensive comments are added to the comment section for tenure tracking purposes.

# %%
query = "reports required for cost center changes"


response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# For cost center changes, the following reports are required:
#
# 1. **VMS Report Post-Update**: This report confirms that all changes related to cost center updates have been applied correctly across all relevant fields.
#
# 2. **Historical Changes Audit Report**: This report audits historical changes to identify trends or recurring issues related to cost center modifications.
#
# 3. **Billing and Invoicing Error Report**: If there are billing and invoicing errors, this report helps check the cost centers and business units of the worker to identify any discrepancies.
#
# 4. **Custom Analytics Report**: The TAPFIN Interactive Dashboard can be utilized for relevant backup data that assists with project auditing purposes related to cost center changes.
#
# These reports will help ensure that cost center changes are accurately reflected and managed within the system.

# %%
query = "reports required for costsaving recommendations"


response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# To generate cost-saving recommendations, the following reports are required:
#
# 1. **Cost Savings Reports**: These should be run per contract requirements or obtained from the Business Intelligence (BI) team to analyze overall savings.
#
# 2. **OT/DT Usage Reports**: Analyze overtime and double time usage to identify potential areas for rate reduction.
#
# 3. **Spend by Supplier Reports**: Review volume discounts and spending patterns across different suppliers to identify opportunities for negotiation.
#
# 4. **Average Tenure Reports**: Assess average tenure to determine if tenure discounts can be applied effectively.
#
# 5. **Custom Analytics Reports**: Utilize the TAPFIN Standard Cost Savings Workbook to track rate card savings, overtime savings, and payroll savings.
#
# 6. **Insights Hub Reports**: Use tools like the Bill Rate Tool and Tenure Insight to gain further insights into cost-saving opportunities.
#
# These reports will help in evaluating current spending, identifying trends, and making informed recommendations for cost savings.

# %%
query = "Initial list of steps for costsaving recommendations"


response_recursive_gpt4o_mini = recursive_query_engine_gpt4o_mini.query(query)

# %%
print("----------------------RESPONSE WITH GPT4O-MINI----------------------")
display(Markdown(f"{response_recursive_gpt4o_mini}"))
# Out:
# ----------------------RESPONSE WITH GPT4O-MINI----------------------
# 1. Run cost savings reports per contract requirements (or obtain from BI).
# 2. Provide these reports to the client on a regular basis (at least quarterly) to demonstrate one of the many benefits of the program.
# 3. Complete an analysis of VMS reports to project the cost savings for each initiative and make recommendations beneficial to the client and TAPFIN.
# 4. Run specific VMS reports for potential cost-saving initiatives, such as:
#    - OT/DT usage - Rate reduction
#    - Spend by Supplier - Volume discount
#    - Average tenure - Tenure discount.
